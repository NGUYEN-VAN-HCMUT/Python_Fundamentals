# %% [markdown]
# <a href="https://colab.research.google.com/github/NGUYEN-VAN-HCMUT/Python_Fundamentals/blob/main/Basic_python_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1.   **Mathematical Functions**

# %% [markdown]
# ore Python supports only the following mathematical functions:
#
#         abs(a) Absolute value of a
#
#         max(sequence) Largest element of sequence
#
#         min(sequence) Smallest element of sequence
#
#         round(a,n) Round a to n decimal places ⎧
#
#         cmp(a,b)
#
# $$\text{Returns}\left\{\begin{matrix}
#  -1 & a < b\\
#   0 & a = b\\
#   1 & a > b
# \end{matrix}\right.$$
#
# The majority of mathematical functions are available in the math module.
